# %% [markdown]
# <a href="https://colab.research.google.com/github/dana-almestadi/Tasks-week1/blob/Task1/Task_(1)_Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dataset Description

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
df=pd.read_csv('/content/drive/MyDrive/Task1/Task (1) Dataset.csv')
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
df.fillna('empty', inplace=True)

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                empty
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
display(df)
# Out:
#                      Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0     2024-07-25 17:02:00      Monday              18-30          Male
# 1     2024-07-25 17:02:00      Monday              31-50          Male
# 2     2024-07-25 17:02:00      Monday              18-30          Male
# 3     2024-07-25 01:06:00      Sunday              18-30          Male
# 4     2024-07-25 01:06:00      Sunday              18-30          Male
# ...                   ...         ...                ...           ...
# 12311 2024-07-25 16:15:00   Wednesday              31-50          Male
# 12312 2024-07-25 18:00:00      Sunday            Unknown          Male
# 12313 2024-07-25 13:55:00      Sunday            Over 51          Male
# 12314 2024-07-25 13:55:00      Sunday              18-30        Female
# 12315 2024-07-25 13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df['Type_of_vehicle']=df['Type_of_vehicle'].replace('Lorry (11?40Q)','Truck')
df['Type_of_vehicle']=df['Type_of_vehicle'].replace('Public (> 45 seats)' ,'Bus')
df['Type_of_vehicle']=df['Type_of_vehicle'].replace('Public (13?45 seats)','Bus')
df['Type_of_vehicle']=df['Type_of_vehicle'].replace('Stationwagen','Manul')
df['Type_of_vehicle']=df['Type_of_vehicle'].replace('Pick up upto 10Q','Truck')
df['Type_of_vehicle']=df['Type_of_vehicle'].replace('Lorry (41?100Q)','Bus')
df['Type_of_vehicle']=df['Type_of_vehicle'].replace('Long lorry','Bus')
df['Type_of_vehicle']=df['Type_of_vehicle'].replace('Taxi','Automobile')
df['Type_of_vehicle']=df['Type_of_vehicle'].replace('Bajaj','Motorcycle')
df['Type_of_vehicle']=df['Type_of_vehicle'].replace('Public (12 seats)','Truck')
df['Type_of_vehicle']=df['Type_of_vehicle'].replace('Turbo','Manul')
df['Type_of_vehicle']=df['Type_of_vehicle'].replace('Special vehicle','Other')
df['Type_of_vehicle']=df['Type_of_vehicle'].replace('Ridden horse','Other')
df['Type_of_vehicle']=df['Type_of_vehicle'].replace('Bicycle','Other')
df['Type_of_vehicle']=df['Type_of_vehicle'].replace('Motorcycle','Other')

# %%
df['Type_of_vehicle'].value_counts()
# Out:
# Type_of_vehicle
# Bus           3505
# Automobile    3251
# Truck         2063
# Other         1595
# Manul          952
# empty          950
# Name: count, dtype: int64

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df['Time'] = pd.to_datetime(df['Time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  datetime64[ns]
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            12316 non-null  object
#  5   Vehicle_driver_relation      12316 non-null  object
#  6   Driving_experience           12316 non-null  object
#  7   Type_of_vehicle              12316 non-null  object
#  8   Owner_of_vehicle             12316 non-null  object
#  9   Service_year_of_vehicle      12316 non-null  object
#  10  Defect_of_vehicle            12316 non-null  object
#  11  Area_accident_occured        12316 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe().round(0)
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                      12316.0               12316.0
# mean                           2.0                   2.0
# std                            1.0                   1.0
# min                            1.0                   1.0
# 25%                            2.0                   1.0
# 50%                            2.0                   1.0
# 75%                            2.0                   2.0
# max                            7.0                   8.0

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df.groupby(['Type_of_vehicle','Number_of_casualties'])[['Age_band_of_casualty']].value_counts()
# Out:
# Type_of_vehicle  Number_of_casualties  Age_band_of_casualty
# Automobile       1                     na                      823
#                                        18-30                   563
#                                        31-50                   430
#                                        Under 18                199
#                                        Over 51                 167
#                                                               ...
# empty            6                     na                        1
#                  7                     18-30                     2
#                                        Over 51                   2
#                                        31-50                     1
#                                        na                        1
# Name: count, Length: 221, dtype: int64

# %%
df.groupby(['Sex_of_driver','Age_band_of_driver'])[['Number_of_casualties']].value_counts()
# Out:
# Sex_of_driver  Age_band_of_driver  Number_of_casualties
# Female         18-30               1                       33
#                                    2                       13
#                                    3                        5
#                                    5                        3
#                                    4                        1
#                                                            ..
# Unknown        Under 18            2                        2
#                                    3                        1
#                                    4                        1
#                Unknown             1                       10
#                                    2                        2
# Name: count, Length: 72, dtype: int64

# %%
df['Age_band_of_driver'].value_counts()
# Out:
# Age_band_of_driver
# 18-30       4271
# 31-50       4087
# Over 51     1585
# Unknown     1548
# Under 18     825
# Name: count, dtype: int64

# %%
df.groupby(['Type_of_vehicle','Number_of_casualties'])[['Number_of_vehicles_involved']].count()
# Out:
#                                       Number_of_vehicles_involved
# Type_of_vehicle Number_of_casualties
# Automobile      1                                            2212
#                 2                                             625
#                 3                                             248
#                 4                                              90
#                 5                                              54
#                 6                                              13
#                 7                                               7
#                 8                                               2
# Bus             1                                            2439
#                 2                                             601
#                 3                                             242
#                 4                                             117
#                 5                                              59
# ...

# %%
df.groupby(['Sex_of_casualty','Age_band_of_casualty'])[['Number_of_casualties']].count()
# Out:
#                                       Number_of_casualties
# Sex_of_casualty Age_band_of_casualty
# Female          18-30                                  966
#                 31-50                                  754
#                 5                                       78
#                 Over 51                                443
#                 Under 18                               379
# Male            18-30                                 2179
#                 31-50                                 1701
#                 5                                      166
#                 Over 51                                551
#                 Under 18                               656
# na              na                                    4443

# %%
df.groupby(['Type_of_vehicle','Weather_conditions'])[['Number_of_casualties']].count()
# Out:
#                                     Number_of_casualties
# Type_of_vehicle Weather_conditions
# Automobile      Cloudy                                38
#                 Fog or mist                            2
#                 Normal                              2661
#                 Other                                 75
#                 Raining                              344
#                 Raining and Windy                     11
#                 Snow                                  14
#                 Unknown                               83
#                 Windy                                 23
# Bus             Cloudy                                40
#                 Fog or mist                            2
#                 Normal                              2860
#                 Other                                 77
#                 Raining                              394
#                 Raining and Windy                     10
# ...

# %%
df.groupby(['Type_of_vehicle','Cause_of_accident'])[['Number_of_casualties']].count()
# Out:
#                                             Number_of_casualties
# Type_of_vehicle Cause_of_accident
# Automobile      Changing lane to the left                    383
#                 Changing lane to the right                   483
#                 Driving at high speed                         49
#                 Driving carelessly                           378
#                 Driving to the left                           76
# ...                                                          ...
# empty           Overspeed                                      3
#                 Overtaking                                    26
#                 Overturning                                   10
#                 Turnover                                       6
#                 Unknown                                        4
#
# [119 rows x 1 columns]

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
sns.histplot(data=df ,x='Age_band_of_driver')
plt.show()

# %%
sns.histplot(data=df ,x='Age_band_of_casualty')
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
sns.scatterplot(data=df,x='Type_of_vehicle',y='Cause_of_accident')
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.barplot(data=df,x='Sex_of_casualty',y='Age_band_of_casualty')
plt.show()

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
sns.histplot(data=df,x='Type_of_vehicle')
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
# the highest Age band of casualty between 18-39
# most incident happened in rainy weather which means the weather has huge impact on the incidents
# most incidents were made by Automobile veichle and Buses
# the age of drivers usually between 18-30
#most incidents happend when the driver was Changing lane to the right by automobile viechle
#most of casualty under age of 18 are females
