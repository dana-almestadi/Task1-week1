# %% [markdown]
# <a href="https://colab.research.google.com/github/dana-almestadi/Tasks-week1/blob/Task2/Task_(2)_Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Objective
# * The objective of this exercise is to explore and visualize the Traffic Index dataset to gain insights and understand the patterns in the data.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('/content/drive/MyDrive/Tasks/Task (2) Dataset.csv')
df.head()
# Out:
#        City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 0  Abudhabi  2023-07-07 08:01:30                 6          4       15.6
# 1  Abudhabi  2023-07-07 09:01:30                 7          7       20.5
# 2  Abudhabi  2023-07-07 10:46:30                 7          8       25.0
# 3  Abudhabi  2023-07-07 11:16:30                 8         11       30.6
# 4  Abudhabi  2023-07-07 12:01:30                 8         20       62.1
#
#    JamsLength  TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# 0         0.7                   13           59.611918       54.803617
# 1         1.7                    8           60.221387       56.118629
# 2         2.8                    6           59.161978       55.518834
# 3         5.5                    6           59.738138       56.413917
# 4         6.5                    5           58.958314       56.059246

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66639 entries, 0 to 66638
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 66639 non-null  object
#  1   Datetime             66639 non-null  object
#  2   TrafficIndexLive     66639 non-null  int64
#  3   JamsCount            66639 non-null  int64
#  4   JamsDelay            66639 non-null  float64
#  5   JamsLength           66639 non-null  float64
#  6   TrafficIndexWeekAgo  66639 non-null  int64
#  7   TravelTimeHistoric   62772 non-null  float64
#  8   TravelTimeLive       62772 non-null  float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 4.6+ MB

# %% [markdown]
# ##Dataset Description

# %% [markdown]
# | Column Name | Description | Data Type |
# | :---------------- | :------: | ----: |
# |   City  |   Name of the city	   | Object |
# | Datetime           |   Date and time of the data entry	   | Object |
# |  TrafficIndexLive    |  Real-time traffic index	   | Int |
# |  Jamscount |  Number of traffic jams	   | Int |
# |   JamsDelay  |   Total delay caused by traffic jams (in minutes)	   | Float |
# |JamsLength           |   Total length of traffic jams (in kilometers)	   | Float |
# |  TrafficIndexWeekAgo    |  Traffic index one week ago	   | Int |
# |  TravelTimeHistoric |  Historical average travel time (in minutes)	   | Float |
# |   TravelTimeLive  |   Real-time travel time (in minutes)	   | Float |

# %% [markdown]
# # Tasks

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe().round(0)
# Out:
#        TrafficIndexLive  JamsCount  JamsDelay  JamsLength  \
# count           66639.0    66639.0    66639.0     66639.0
# mean               14.0       74.0      288.0        49.0
# std                13.0      107.0      470.0        85.0
# min                 0.0        0.0        0.0         0.0
# 25%                 3.0        9.0       28.0         3.0
# 50%                10.0       29.0       96.0        12.0
# 75%                21.0       95.0      337.0        54.0
# max               138.0     1359.0     9989.0      1174.0
#
#        TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# count              66639.0             62772.0         62772.0
# mean                  14.0                71.0            70.0
# std                   13.0                11.0            12.0
# min                    0.0                49.0            47.0
# 25%                    3.0                63.0            61.0
# 50%                   10.0                69.0            68.0
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66639 entries, 0 to 66638
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 66639 non-null  object
#  1   Datetime             66639 non-null  object
#  2   TrafficIndexLive     66639 non-null  int64
#  3   JamsCount            66639 non-null  int64
#  4   JamsDelay            66639 non-null  float64
#  5   JamsLength           66639 non-null  float64
#  6   TrafficIndexWeekAgo  66639 non-null  int64
#  7   TravelTimeHistoric   62772 non-null  float64
#  8   TravelTimeLive       62772 non-null  float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 4.6+ MB

# %%
df['JamsDelay'].mean()
# Out:
# 288.35387685889646

# %%
df.groupby(['Datetime' ,'City'])['JamsDelay'].max().round(0)
# Out:
# Datetime             City
# 2022-12-16 11:01:30  Cairo      86.0
# 2022-12-16 12:01:30  Cairo      59.0
# 2022-12-16 12:46:30  Doha       29.0
#                      Kuwait     68.0
#                      Riyadh    115.0
#                                ...
# 2023-12-15 07:16:30  Doha       46.0
# 2023-12-15 07:31:30  Dammam     20.0
# 2023-12-15 07:46:30  Al-ain      6.0
#                      Dubai     649.0
# 2023-12-15 08:46:30  Dubai     874.0
# Name: JamsDelay, Length: 66639, dtype: float64

# %%
df.groupby('City')['JamsDelay'].mean().round(0)
# Out:
# City
# Abudhabi    108.0
# Al-ain       23.0
# Cairo       269.0
# Dammam      123.0
# Doha        128.0
# Dubai       717.0
# Jeddah      182.0
# Kuwait      248.0
# Mecca        43.0
# Medina       37.0
# Riyadh      620.0
# Name: JamsDelay, dtype: float64

# %%
df.groupby(['City', 'JamsDelay']).max()
# Out:
#                                Datetime  TrafficIndexLive  JamsCount  \
# City     JamsDelay
# Abudhabi 0.0        2023-12-15 03:01:30                11          0
#          0.5        2023-11-30 03:01:30                 4          1
#          0.6        2023-12-05 03:31:30                 4          1
#          0.7        2023-11-20 03:16:30                 3          1
#          0.8        2023-12-10 04:46:30                 4          1
# ...                                 ...               ...        ...
# Riyadh   4493.8     2023-01-02 17:16:00                99        757
#          4692.4     2023-09-23 21:46:30                84        633
#          4764.9     2023-09-23 22:01:00                84        642
#          5379.8     2023-03-15 17:31:00                98        883
#          5466.3     2023-03-15 18:01:00                94        797
#
#                     JamsLength  TrafficIndexWeekAgo  TravelTimeHistoric  \
# City     JamsDelay
# ...

# %%
df.groupby(['City','TrafficIndexLive'])['TrafficIndexWeekAgo'].count()
# Out:
# City      TrafficIndexLive
# Abudhabi  0                     3
#           1                    49
#           2                   184
#           3                   283
#           4                   270
#                              ...
# Riyadh    94                    1
#           95                    1
#           96                    3
#           98                    2
#           99                    1
# Name: TrafficIndexWeekAgo, Length: 668, dtype: int64

# %%
df.groupby(['City','JamsCount']).max().round(0)
# Out:
#                                Datetime  TrafficIndexLive  JamsDelay  \
# City     JamsCount
# Abudhabi 0          2023-12-15 03:01:30                11        0.0
#          1          2023-12-15 01:01:30                 7       12.0
#          2          2023-12-13 02:16:30                10       22.0
#          3          2023-12-15 05:01:30                11       25.0
#          4          2023-12-15 04:31:30                11       36.0
# ...                                 ...               ...        ...
# Riyadh   757        2023-01-02 17:16:00                99     4494.0
#          767        2023-01-02 16:46:00                98     4410.0
#          778        2023-11-16 18:01:00                95     4465.0
#          797        2023-03-15 18:01:00                94     5466.0
#          883        2023-03-15 17:31:00                98     5380.0
#
#                     JamsLength  TrafficIndexWeekAgo  TravelTimeHistoric  \
# City     JamsCount
# ...

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Traffic_Index, Date).

# %%
sns.scatterplot(data=df, x='TrafficIndexLive', y='TrafficIndexWeekAgo')
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Traffic_Index vs. Weather_Condition).

# %%
sns.scatterplot(data=df, x='TrafficIndexLive', y='JamsDelay')
plt.show()

# %% [markdown]
# ## 2. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.barplot(data=df, x='City', y='JamsDelay')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
sns.histplot(data=df, x='City', y='TrafficIndexLive')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 3. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
#the highest jams delay and jams count  is  in Dubai
#the lowest jams delay and jams count  is in Al-ain
#the traffic live index is higher than the traffic live index a week ago
#the highest mean Jams delay city has is in kuwait
# the highest traffic live index is in Dubai
#the highest jams delay happened in Dubai at 8:46 AM
